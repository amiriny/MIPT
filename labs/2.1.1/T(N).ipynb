# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# данные

my_data = genfromtxt('first.csv', delimiter=',')

first, second, xerr, yerr = [], [], [], []
for element in my_data:
    second.append(element[2])
    yerr.append(element[3])
    first.append(element[0])
    xerr.append(element[1])

x = np.array(first)
y = np.array(second)

dx = np.array(xerr)
dy = np.array(yerr)

# метод наименьших квадратов
p, V = np.polyfit(x, y, 1, cov=True)
y_fit = np.polyval(p, x)

# построение графика
plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='data')
plt.plot(x, y_fit)

# вывод коэффициента наклона с погрешностью
slope = p[0]
slope_error = np.sqrt(V[0][0])

b = p[1]
b_error = np.sqrt(V[1][1])

print('Коэффициент наклона: {:.5f} ± {:.5f}'.format(slope, slope_error))
print('Свободный параметр: {:.5f} ± {:.5f}'.format(b, b_error))

plt.text(0.5, 3, 'y = {:.2f}x + {:.2f}'.format(slope, b))


# название графика 
plt.title('$ \Delta T(N) $')

# название горизонтальной оси 
plt.xlabel('N, Вт')

# название вертикальной оси
plt.ylabel('$ \Delta T $, K')

plt.grid()

plt.legend()
plt.show()
# Out:
# Коэффициент наклона: 7.06417 ± 0.12811
# Свободный параметр: 0.00383 ± 0.10388

# %%
my_data = genfromtxt('second.csv', delimiter=',')

first, second, xerr, yerr = [], [], [], []
for element in my_data:
    second.append(element[2])
    yerr.append(element[3])
    first.append(element[0])
    xerr.append(element[1])

x = np.array(first)
y = np.array(second)

dx = np.array(xerr)
dy = np.array(yerr)

# метод наименьших квадратов
p, V = np.polyfit(x, y, 1, cov=True)
y_fit = np.polyval(p, x)

# построение графика
plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='data')
plt.plot(x, y_fit)

# вывод коэффициента наклона с погрешностью
slope = p[0]
slope_error = np.sqrt(V[0][0])

b = p[1]
b_error = np.sqrt(V[1][1])

print('Коэффициент наклона: {:.5f} ± {:.5f}'.format(slope, slope_error))
print('Свободный параметр: {:.5f} ± {:.5f}'.format(b, b_error))

plt.text(0.5, 1.7, 'y = {:.2f}x + {:.2f}'.format(slope, b))


# название графика 
plt.title('$ \Delta T(N) $')

# название горизонтальной оси 
plt.xlabel('N, Вт')

# название вертикальной оси
plt.ylabel('$ \Delta T $, K')

plt.grid()

plt.legend()
plt.show()
# Out:
# Коэффициент наклона: 4.34399 ± 0.03363
# Свободный параметр: 0.09168 ± 0.04003

# %%
my_data = genfromtxt('k(q).csv', delimiter=',')

first, second, xerr, yerr = [], [], [], []
for element in my_data:
    second.append(element[0])
    yerr.append(element[1])
    first.append(element[2])
    xerr.append(element[3])

x = np.array(first)
y = np.array(second)

dx = np.array(xerr)
dy = np.array(yerr)

# метод наименьших квадратов
p = np.polyfit(x, y, 1, cov=False)
y_fit = np.polyval(p, x)

# построение графика
plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='data')
plt.plot(x, y_fit)

# вывод коэффициента наклона с погрешностью
slope = p[0]
slope_error = 0

b = p[1]
b_error = 0

print('Коэффициент наклона: {:.5f} ± {:.5f}'.format(slope, slope_error))
print('Свободный параметр: {:.5f} ± {:.5f}'.format(b, b_error))

plt.text(0.15, 4.4, 'y = {:.2f}x + {:.2f}'.format(slope, b))


# название графика 
plt.title('$ k_{накл}(q) $')

# название горизонтальной оси 
plt.xlabel('$q$, г / с')

# название вертикальной оси
plt.ylabel('$ k_{накл} $, К / Вт')

plt.grid()

plt.legend()
plt.show()
# Out:
# Коэффициент наклона: -34.43038 ± 0.00000
# Свободный параметр: 10.91620 ± 0.00000

# %%
my_data = genfromtxt('k(q).csv', delimiter=',')

first, second, xerr, yerr = [], [], [], []
for element in my_data:
    second.append(element[2])
    yerr.append(element[3])
    first.append(element[0])
    xerr.append(element[1])

x = np.array(first)
y = np.array(second)

dx = np.array(xerr)
dy = np.array(yerr)

# метод наименьших квадратов
p = np.polyfit(x, y, 1, cov=False)
y_fit = np.polyval(p, x)

# построение графика
plt.errorbar(x, y, xerr=dx, yerr=dy, fmt='o', label='data')
plt.plot(x, y_fit)

# вывод коэффициента наклона с погрешностью
slope = p[0]
slope_error = 0

b = p[1]
b_error = 0

print('Коэффициент наклона: {:.5f} ± {:.5f}'.format(slope, slope_error))
print('Свободный параметр: {:.5f} ± {:.5f}'.format(b, b_error))

plt.text(4.4, 0.15, 'y = {:.2f}x + {:.2f}'.format(slope, b))


# название графика 
plt.title('$ k_{накл}(q) $')

# название горизонтальной оси 
plt.xlabel('$q$, г / с')

# название вертикальной оси
plt.ylabel('$ k_{накл} $, К / Вт')

plt.grid()

plt.legend()
plt.show()
# Out:
# Коэффициент наклона: -0.02904 ± 0.00000
# Свободный параметр: 0.31705 ± 0.00000
