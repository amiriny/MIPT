# %%
import pandas as pd
import numpy as np
from numpy import genfromtxt
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# данные

my_data = genfromtxt('kappa.csv', delimiter=',')

first, second, xerr, yerr = [], [], [], []
for element in my_data:
    first.append(element[0])
    second.append(element[1])
    yerr.append(element[2])

# del first[0]
# del second[0]
# del xerr[0]
# del yerr[0]

x = np.array(first)
y = np.array(second)

dx = np.array(xerr)
dy = np.array(yerr)

# метод наименьших квадратов
p, V = np.polyfit(x, y, 1, cov=True)
y_fit = np.polyval(p, x)

# построение графика
plt.errorbar(x, y, yerr=dy, fmt='o', label='data')
plt.plot(x, y_fit)


# вывод коэффициента наклона с погрешностью
slope = p[0]
slope_error = np.sqrt(V[0][0])
# print('Slope: {:.5f} ± {:.5f}'.format(slope, slope_error))

ymean = np.mean(y)
xmean = np.mean(x)
b = ymean - slope * xmean
print('Уравнение прямой: y = {:.5f}x + {:.5f}'.format(slope, b))
slopeerror = np.sqrt(V[0][0])
print('Slope: {:.5f} ± {:.5f}'.format(slope, slopeerror))
print('Свободный параметр: {:.5f}'.format(b))

# название графика 
#plt.title('$R(T)$')

plt.text(300, 0.39, 'y = {:.3f}x + {:.3f}'.format(slope, b))

# название горизонтальной оси 
plt.xlabel('$T$, K')

# название вертикальной оси
plt.ylabel('$\kappa$ $\dfrac{мВт}{м \cdot К}$')

plt.grid()

plt.legend()
plt.show()
# Out:
# Уравнение прямой: y = 0.00080x + 0.16610
# Slope: 0.00080 ± 0.00016
# Свободный параметр: 0.16610
